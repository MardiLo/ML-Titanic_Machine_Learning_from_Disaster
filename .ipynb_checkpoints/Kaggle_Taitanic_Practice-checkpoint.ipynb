# %% [markdown]
# ## Outline
# ### 1.First thing first
# + Import library packages
# + Load dataset
# + Overview of dataset
#
# ### 2.Feature analysis, Feature engineering and Filling missing values
# + Sex
# + Pclass
# + Fare
# + Ticket Connection
# + Age
#
# ### 3.Hyper-parameters searching
#
# ### 4.Failed attempts
# + Performance on other models with hyper-parameters searching
# + Model ensembling
# + Review on failure
#
# ### 5.Reference
# + [Titanic Top 4% with ensemble modeling](https://www.kaggle.com/yassineghouzam/titanic-top-4-with-ensemble-modeling)
# + [[機器學習專案] Kaggle競賽-鐵達尼號生存預測(Top 3%)](https://medium.com/@yulongtsai/https-medium-com-yulongtsai-titanic-top3-8e64741cc11f)

# %% [markdown]
# ## 1.First thing first

# %% [markdown]
# ### Import library packages

# %%
# Import Common Library Packages
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# Import Machine Learning Library Packages
from sklearn.ensemble import RandomForestClassifier
from sklearn.preprocessing import LabelEncoder
from sklearn.model_selection import GridSearchCV, cross_val_score, StratifiedKFold, learning_curve
from collections import Counter

# Disable warnings
import warnings

# %matplotlib inline
sns.set(font_scale=1.5)
plt.style.use(style='ggplot')
warnings.filterwarnings('ignore')

# %% [markdown]
# ### Load dataset

# %%
df_train = pd.read_csv("train.csv")
df_test = pd.read_csv("test.csv")

# Dataset preprocessing
df_data = df_train.append(df_test)  # combine training set and testing set
df_data.reset_index(inplace=True, drop=True)  # reset dataset index

# %%
df_data
# Out:
#        Age        Cabin Embarked      Fare  \
# 0     22.0          NaN        S    7.2500
# 1     38.0          C85        C   71.2833
# 2     26.0          NaN        S    7.9250
# 3     35.0         C123        S   53.1000
# 4     35.0          NaN        S    8.0500
# 5      NaN          NaN        Q    8.4583
# 6     54.0          E46        S   51.8625
# 7      2.0          NaN        S   21.0750
# 8     27.0          NaN        S   11.1333
# 9     14.0          NaN        C   30.0708
# 10     4.0           G6        S   16.7000
# 11    58.0         C103        S   26.5500
# 12    20.0          NaN        S    8.0500
# 13    39.0          NaN        S   31.2750
# 14    14.0          NaN        S    7.8542
# 15    55.0          NaN        S   16.0000
# 16     2.0          NaN        Q   29.1250
# 17     NaN          NaN        S   13.0000
# 18    31.0          NaN        S   18.0000
# 19     NaN          NaN        C    7.2250
# 20    35.0          NaN        S   26.0000
# 21    34.0          D56        S   13.0000
# 22    15.0          NaN        Q    8.0292
# 23    28.0           A6        S   35.5000
# 24     8.0          NaN        S   21.0750
# 25    38.0          NaN        S   31.3875
# 26     NaN          NaN        C    7.2250
# 27    19.0  C23 C25 C27        S  263.0000
# 28     NaN          NaN        Q    7.8792
# 29     NaN          NaN        S    7.8958
# ...    ...          ...      ...       ...
# 1279  21.0          NaN        Q    7.7500
# 1280   6.0          NaN        S   21.0750
# 1281  23.0          B24        S   93.5000
# 1282  51.0          D28        S   39.4000
# 1283  13.0          NaN        S   20.2500
# 1284  47.0          NaN        S   10.5000
# 1285  29.0          NaN        S   22.0250
# 1286  18.0          C31        S   60.0000
# 1287  24.0          NaN        Q    7.2500
# 1288  48.0          B41        C   79.2000
# 1289  22.0          NaN        S    7.7750
# 1290  31.0          NaN        Q    7.7333
# 1291  30.0           C7        S  164.8667
# 1292  38.0          NaN        S   21.0000
# 1293  22.0          NaN        C   59.4000
# 1294  17.0          NaN        S   47.1000
# 1297                          Ware, Mr. William Jeffery      0         1298
# 1298                         Widener, Mr. George Dunton      1         1299
# 1299                    Riordan, Miss. Johanna Hannah""      0         1300
# 1300                          Peacock, Miss. Treasteall      1         1301
# 1301                             Naughton, Miss. Hannah      0         1302
# 1302    Minahan, Mrs. William Edward (Lillian E Thorpe)      0         1303
# 1303                     Henriksson, Miss. Jenny Lovisa      0         1304
# 1304                                 Spector, Mr. Woolf      0         1305
# 1305                       Oliva y Ocana, Dona. Fermina      0         1306
# 1306                       Saether, Mr. Simon Sivertsen      0         1307
# 1307                                Ware, Mr. Frederick      0         1308
# 1308                           Peter, Master. Michael J      1         1309
#
#       Pclass     Sex  SibSp  Survived              Ticket
# 0          3    male      1       0.0           A/5 21171
# 1          1  female      1       1.0            PC 17599
# 2          3  female      0       1.0    STON/O2. 3101282
# 3          1  female      1       1.0              113803
# 4          3    male      0       0.0              373450
# 5          3    male      0       0.0              330877
# 6          1    male      0       0.0               17463
# 7          3    male      3       0.0              349909
# 8          3  female      0       1.0              347742
# 9          2  female      1       1.0              237736
# 10         3  female      1       1.0             PP 9549
# 11         1  female      0       1.0              113783
# 12         3    male      0       0.0           A/5. 2151
# 13         3    male      1       0.0              347082
# 14         3  female      0       0.0              350406
# 15         2  female      0       1.0              248706
# 16         3    male      4       0.0              382652
# 17         2    male      0       1.0              244373
# 18         3  female      1       0.0              345763
# 19         3  female      0       1.0                2649
# 20         2    male      0       0.0              239865
# 21         2    male      0       1.0              248698
# 22         3  female      0       1.0              330923
# 23         1    male      0       1.0              113788
# 24         3  female      3       0.0              349909
# 25         3  female      1       1.0              347077
# 26         3    male      0       0.0                2631
# 27         1    male      3       0.0               19950
# 28         3  female      0       1.0              330959
# 29         3    male      0       0.0              349216
# ...      ...     ...    ...       ...                 ...
# 1279       3    male      0       NaN              364858
# 1280       3    male      3       NaN              349909
# 1281       1    male      0       NaN               12749
# 1282       1  female      0       NaN            PC 17592
# 1283       3    male      0       NaN           C.A. 2673
# 1284       2    male      0       NaN          C.A. 30769
# 1285       3    male      3       NaN              315153
# 1286       1  female      1       NaN               13695
# 1287       3    male      0       NaN              371109
# 1288       1  female      1       NaN               13567
# 1289       3    male      0       NaN              347065
# 1290       3    male      0       NaN               21332
# 1291       1  female      0       NaN               36928
# 1292       2    male      1       NaN               28664
# 1293       1  female      0       NaN              112378
# 1294       1    male      0       NaN              113059
# 1295       1    male      1       NaN               17765
# 1296       2    male      0       NaN       SC/PARIS 2166
# 1297       2    male      1       NaN               28666
# 1298       1    male      1       NaN              113503
# 1299       3  female      0       NaN              334915
# 1300       3  female      1       NaN  SOTON/O.Q. 3101315
# 1301       3  female      0       NaN              365237
# 1302       1  female      1       NaN               19928
# 1303       3  female      0       NaN              347086
# 1304       3    male      0       NaN           A.5. 3236
# 1305       1  female      0       NaN            PC 17758
# 1306       3    male      0       NaN  SOTON/O.Q. 3101262
# 1307       3    male      0       NaN              359309
# 1308       3    male      1       NaN                2668
#
# [1309 rows x 12 columns]

# %% [markdown]
# ### Overview of dataset
# + **Age**, **Cabin**,and **Embarked** have missing values

# %%
df_train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
# PassengerId    891 non-null int64
# Survived       891 non-null int64
# Pclass         891 non-null int64
# Name           891 non-null object
# Sex            891 non-null object
# Age            714 non-null float64
# SibSp          891 non-null int64
# Parch          891 non-null int64
# Ticket         891 non-null object
# Fare           891 non-null float64
# Cabin          204 non-null object
# Embarked       889 non-null object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.6+ KB

# %%
df_test.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 418 entries, 0 to 417
# Data columns (total 11 columns):
# PassengerId    418 non-null int64
# Pclass         418 non-null int64
# Name           418 non-null object
# Sex            418 non-null object
# Age            332 non-null float64
# SibSp          418 non-null int64
# Parch          418 non-null int64
# Ticket         418 non-null object
# Fare           417 non-null float64
# Cabin          91 non-null object
# Embarked       418 non-null object
# dtypes: float64(2), int64(4), object(5)
# memory usage: 36.0+ KB

# %%
df_train.describe()
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   891.000000  891.000000  891.000000  714.000000  891.000000
# mean    446.000000    0.383838    2.308642   29.699118    0.523008
# std     257.353842    0.486592    0.836071   14.526497    1.102743
# min       1.000000    0.000000    1.000000    0.420000    0.000000
# 25%     223.500000    0.000000    2.000000   20.125000    0.000000
# 50%     446.000000    0.000000    3.000000   28.000000    0.000000
# 75%     668.500000    1.000000    3.000000   38.000000    1.000000
# max     891.000000    1.000000    3.000000   80.000000    8.000000
#
#             Parch        Fare
# count  891.000000  891.000000
# mean     0.381594   32.204208
# std      0.806057   49.693429
# min      0.000000    0.000000
# 25%      0.000000    7.910400
# 50%      0.000000   14.454200
# 75%      0.000000   31.000000
# max      6.000000  512.329200

# %%
df_test.describe()
# Out:
#        PassengerId      Pclass         Age       SibSp       Parch        Fare
# count   418.000000  418.000000  332.000000  418.000000  418.000000  417.000000
# mean   1100.500000    2.265550   30.272590    0.447368    0.392344   35.627188
# std     120.810458    0.841838   14.181209    0.896760    0.981429   55.907576
# min     892.000000    1.000000    0.170000    0.000000    0.000000    0.000000
# 25%     996.250000    1.000000   21.000000    0.000000    0.000000    7.895800
# 50%    1100.500000    3.000000   27.000000    0.000000    0.000000   14.454200
# 75%    1204.750000    3.000000   39.000000    1.000000    0.000000   31.500000
# max    1309.000000    3.000000   76.000000    8.000000    9.000000  512.329200

# %% [markdown]
# ## 2.Feature analysis, Feature engineering and Filling missing values
# + In this part, we'll explore vital features by SFS (Sequential Forward Selection) method ([More about feature selection technique](https://blog.csdn.net/jusang486/article/details/46405735))

# %% [markdown]
# ### 1. Survival rate vs Sex
# + Male: 0.189
# + Female: 0.742
# + Overall: 0.384
# + Interpretation: Let female escape first
# + LB: 0.76555, CV: 0.78676

# %% [markdown]
# #### Feature analysis

# %%
# Data processing
all_suvrate = round(df_train['Survived'].mean(), 3)  # cal. total survival rate
df_all_suvrate = pd.DataFrame(all_suvrate, columns=['Survival_rate'], index=['all'])  # put total survival rate into dataframe
df_sex_vs_suvrate = df_train[['Sex', 'Survived']].groupby(['Sex']).mean().round(3)  # cal. survival rate on sex
df_sex_vs_suvrate.columns = ['Survival_rate']  # rename column
display(df_sex_vs_suvrate.append(df_all_suvrate))

# Plotting
plt.figure(figsize = (16,6))  # enlarge figure size
s = sns.countplot(df_train['Sex'], hue=df_train['Survived'])
s.set_xlabel('Sex',fontsize=16)
s.set_ylabel('Count',fontsize=16)
# Out:
#         Survival_rate
# female          0.742
# male            0.189
# all             0.384
# Text(0, 0.5, 'Count')

# %%
#  Label encoding
df_data['Sex_Code'] = df_data['Sex'].map({'female' : 1, 'male' : 0}) # do labelencode on sex

# Dataset observation
cols = ['Name', 'Sex', 'Sex_Code']
df_data.loc[:, cols]
# Out:
#                                                    Name     Sex  Sex_Code
# 0                               Braund, Mr. Owen Harris    male         0
# 1     Cumings, Mrs. John Bradley (Florence Briggs Th...  female         1
# 2                                Heikkinen, Miss. Laina  female         1
# 3          Futrelle, Mrs. Jacques Heath (Lily May Peel)  female         1
# 4                              Allen, Mr. William Henry    male         0
# 5                                      Moran, Mr. James    male         0
# 6                               McCarthy, Mr. Timothy J    male         0
# 7                        Palsson, Master. Gosta Leonard    male         0
# 8     Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)  female         1
# 9                   Nasser, Mrs. Nicholas (Adele Achem)  female         1
# 10                      Sandstrom, Miss. Marguerite Rut  female         1
# 11                             Bonnell, Miss. Elizabeth  female         1
# 12                       Saundercock, Mr. William Henry    male         0
# 13                          Andersson, Mr. Anders Johan    male         0
# 14                 Vestrom, Miss. Hulda Amanda Adolfina  female         1
# 15                     Hewlett, Mrs. (Mary D Kingcome)   female         1
# 16                                 Rice, Master. Eugene    male         0
# 17                         Williams, Mr. Charles Eugene    male         0
# 18    Vander Planke, Mrs. Julius (Emelia Maria Vande...  female         1
# 19                              Masselmani, Mrs. Fatima  female         1
# 20                                 Fynney, Mr. Joseph J    male         0
# 21                                Beesley, Mr. Lawrence    male         0
# 22                          McGowan, Miss. Anna "Annie"  female         1
# 23                         Sloper, Mr. William Thompson    male         0
# 24                        Palsson, Miss. Torborg Danira  female         1
# 25    Asplund, Mrs. Carl Oscar (Selma Augusta Emilia...  female         1
# 26                              Emir, Mr. Farred Chehab    male         0
# 27                       Fortune, Mr. Charles Alexander    male         0
# 28                        O'Dwyer, Miss. Ellen "Nellie"  female         1
# 29                                  Todoroff, Mr. Lalio    male         0
# ...                                                 ...     ...       ...
# 1279                               Canavan, Mr. Patrick    male         0
# 1280                        Palsson, Master. Paul Folke    male         0
# 1281                         Payne, Mr. Vivian Ponsonby    male         0
# 1282     Lines, Mrs. Ernest H (Elizabeth Lindsey James)  female         1
# 1283                      Abbott, Master. Eugene Joseph    male         0
# 1284                               Gilbert, Mr. William    male         0
# 1285                           Kink-Heilmann, Mr. Anton    male         0
# 1286     Smith, Mrs. Lucien Philip (Mary Eloise Hughes)  female         1
# 1287                               Colbert, Mr. Patrick    male         0
# 1288  Frolicher-Stehli, Mrs. Maxmillian (Margaretha ...  female         1
# 1289                     Larsson-Rondberg, Mr. Edvard A    male         0
# 1290                           Conlon, Mr. Thomas Henry    male         0
# 1291                            Bonnell, Miss. Caroline  female         1
# 1292                                    Gale, Mr. Harry    male         0
# 1293                     Gibson, Miss. Dorothy Winifred  female         1
# 1294                             Carrau, Mr. Jose Pedro    male         0
# 1295                       Frauenthal, Mr. Isaac Gerald    male         0
# 1296       Nourney, Mr. Alfred (Baron von Drachstedt")"    male         0
# 1297                          Ware, Mr. William Jeffery    male         0
# 1298                         Widener, Mr. George Dunton    male         0
# 1299                    Riordan, Miss. Johanna Hannah""  female         1
# 1300                          Peacock, Miss. Treasteall  female         1
# 1301                             Naughton, Miss. Hannah  female         1
# 1302    Minahan, Mrs. William Edward (Lillian E Thorpe)  female         1
# 1303                     Henriksson, Miss. Jenny Lovisa  female         1
# 1304                                 Spector, Mr. Woolf    male         0
# 1305                       Oliva y Ocana, Dona. Fermina  female         1
# 1306                       Saether, Mr. Simon Sivertsen    male         0
# 1307                                Ware, Mr. Frederick    male         0
# 1308                           Peter, Master. Michael J    male         0
#
# [1309 rows x 3 columns]

# %% [markdown]
# #### The contribution of variable Sex(X1) on Survived(Y)

# %%
# Data slicing
df_train = df_data[:len(df_train)]
df_test = df_data[len(df_train):]

# Training features selection
X_train = df_train['Sex_Code'].to_frame()  # transform series into dataframe
Y_train = df_train['Survived']

# Model training
model_1 = RandomForestClassifier(random_state=0, n_estimators=250, min_samples_split=20, oob_score=True)
model_1.fit(X_train, Y_train)
print('Out-Of-Bag(oob) score : %.5f' %(model_1.oob_score_))
# Out:
# Out-Of-Bag(oob) score : 0.78676

# %% [markdown]
# #### Export to CSV

# %%
# Training features selection
X_test = df_test['Sex_Code'].to_frame()  # transform series into dataframe

# Predict by model
model_1_prediction = model_1.predict(X_test)
submit_1 = pd.DataFrame({'PassengerId': df_test['PassengerId'], 'Survived': model_1_prediction.astype(int)})
submit_1.to_csv("Model_1.csv", index=False)

# %% [markdown]
# ### 2. Survival rate vs Pclass
# + Class_1: 0.630
# + Class_2: 0.473
# + Class_3: 0.242
# + Overall: 0.384
# + Interpretation: The rich have higher survival rate
# + LB: 0.76555, CV: 0.73737

# %% [markdown]
# #### Feature analysis

# %%
# Data processing
df_pclass_vs_suvrate = df_train[['Pclass', 'Survived']].groupby(['Pclass']).mean().round(3)  # cal. survival rate on cabin class
df_pclass_vs_suvrate.columns = ['Survival_rate']  # rename column
display(df_pclass_vs_suvrate.append(df_all_suvrate))

# Plotting
plt.figure(figsize = (16,6))  # enlarge figure size
s = sns.countplot(df_train['Pclass'], hue=df_train['Survived'])
s.set_xlabel('Pclass',fontsize=16)
s.set_ylabel('Count',fontsize=16)
# Out:
#      Survival_rate
# 1            0.630
# 2            0.473
# 3            0.242
# all          0.384
# Text(0, 0.5, 'Count')

# %% [markdown]
# #### The contribution of variable Pclass(X) on Survived(Y)

# %%
# Data slicing
df_train = df_data[:len(df_train)]
df_test = df_data[len(df_train):]

# Training features selection
X_train = df_train['Pclass'].to_frame()  # transform series into dataframe
Y_train = df_train['Survived']

# Model training
model_2_test = RandomForestClassifier(random_state=0, n_estimators=250, min_samples_split=20, oob_score=True)
model_2_test.fit(X_train, Y_train)
print('Out-Of-Bag(oob) score : %.5f' %(model_2_test.oob_score_))
# Out:
# Out-Of-Bag(oob) score : 0.67901

# %% [markdown]
# #### The contribution of variable Sex(X1), Pclass(X2) on Survived(Y)

# %%
# Training features selection
X_train = df_train[['Sex_Code', 'Pclass']]
Y_train = df_train['Survived']

# Model training
model_2 = RandomForestClassifier(random_state=0, n_estimators=250, min_samples_split=20, oob_score=True)
model_2.fit(X_train, Y_train)
print('Out-Of-Bag(oob) score : %.5f' %(model_2.oob_score_))
# Out:
# Out-Of-Bag(oob) score : 0.73737

# %% [markdown]
# #### Export to CSV

# %%
# Training features selection
X_test = df_test[['Sex_Code', 'Pclass']]

# Predict by model
model_2_prediction = model_2.predict(X_test)
submit_2 = pd.DataFrame({'PassengerId': df_test['PassengerId'], 'Survived': model_2_prediction.astype(int)})
submit_2.to_csv("Model_2.csv", index=False)

# %% [markdown]
# ### 3. Survival rate vs Fare
# + Interpretation: The rich have higher survival rate
# + LB: 0.79425, CV: 0.81033

# %% [markdown]
# #### Feature analysis

# %%
# Data processing
df_train['Log_Fare'] = df_train['Fare'].map(lambda x : np.log10(x) if x > 0 else 0)  # take log on Fare and name this new variable as Log_Fare

# Dataset observation
cols = ['Age', 'Name', 'Sex', 'Ticket', 'Pclass', 'Embarked', 'Fare', 'Log_Fare']
display(df_train.loc[:, cols].head(3))

# Plotting
plt.figure(figsize = (16,6))  # enlarge figure size
s = sns.boxplot(y='Survived', x='Log_Fare', data=df_train, orient='h')
s.set_xlabel('Log_Fare',fontsize=16)
s.set_ylabel('Survived',fontsize=16)
# Out:
#     Age                                               Name     Sex  \
# 0  22.0                            Braund, Mr. Owen Harris    male
# 1  38.0  Cumings, Mrs. John Bradley (Florence Briggs Th...  female
# 2  26.0                             Heikkinen, Miss. Laina  female
#
#              Ticket  Pclass Embarked     Fare  Log_Fare
# 0         A/5 21171       3        S   7.2500  0.860338
# 1          PC 17599       1        C  71.2833  1.852988
# 2  STON/O2. 3101282       3        S   7.9250  0.898999
# Text(0, 0.5, 'Survived')

# %%
# Data preprocessing (filling missing values)
# df_data['Fare'] = df_data['Fare'].fillna(df_data['Fare'].median())  # filling with median value(=14.4542)

# Dataset observation
print('Before filling missing values')
display(df_data.loc[(df_data['Pclass']==3)&(df_data['Age']>60)&(df_data['Sex']=='male')])

# Filling missing values
df_data['surname'] = df_data["Name"].apply(lambda x: x.split(',')[0].lower())  # filling with similar value(=14.4542)
fare_mean_estimated = df_data.loc[(df_data['Pclass']==3)&(df_data['Age']>60)&(df_data['Sex']=='male')].Fare.mean()
df_data.loc[df_data['surname']=='storey','Fare'] = fare_mean_estimated

# Dataset observation
print('\nAfter filling missing values')
display(df_data.loc[(df_data['Pclass']==3)&(df_data['Age']>60)&(df_data['Sex']=='male')])
# Out:
# Before filling missing values
#        Age Cabin Embarked    Fare                       Name  Parch  \
# 116   70.5   NaN        Q  7.7500       Connors, Mr. Patrick      0
# 280   65.0   NaN        Q  7.7500           Duane, Mr. Frank      0
# 326   61.0   NaN        S  6.2375  Nysveen, Mr. Johan Hansen      0
# 851   74.0   NaN        S  7.7750        Svensson, Mr. Johan      0
# 1043  60.5   NaN        S     NaN         Storey, Mr. Thomas      0
#
#       PassengerId  Pclass   Sex  SibSp  Survived  Ticket  Sex_Code
# 116           117       3  male      0       0.0  370369         0
# 280           281       3  male      0       0.0  336439         0
# 326           327       3  male      0       0.0  345364         0
# 851           852       3  male      0       0.0  347060         0
# 1043         1044       3  male      0       NaN    3701         0
# After filling missing values
#        Age Cabin Embarked      Fare                       Name  Parch  \
# 116   70.5   NaN        Q  7.750000       Connors, Mr. Patrick      0
# 280   65.0   NaN        Q  7.750000           Duane, Mr. Frank      0
# 326   61.0   NaN        S  6.237500  Nysveen, Mr. Johan Hansen      0
# 851   74.0   NaN        S  7.775000        Svensson, Mr. Johan      0
# 1043  60.5   NaN        S  7.378125         Storey, Mr. Thomas      0
#
#       PassengerId  Pclass   Sex  SibSp  Survived  Ticket  Sex_Code   surname
# 116           117       3  male      0       0.0  370369         0   connors
# 280           281       3  male      0       0.0  336439         0     duane
# 326           327       3  male      0       0.0  345364         0   nysveen
# 851           852       3  male      0       0.0  347060         0  svensson
# 1043         1044       3  male      0       NaN    3701         0    storey

# %%
# Making fare intervals(1~10 intervals)
for i in range(1,11):
    df_data['Fare_'+str(i)+'int'] = pd.qcut(df_data['Fare'], i)

label = LabelEncoder()
for i in range(1,11):
    # Do labelencode on fare intervals
    df_data['Fare_'+str(i)+'int_Code'] = label.fit_transform(df_data['Fare_'+str(i)+'int'])
    
    # Show the relationship between fare intervals and cabin class
    display(pd.crosstab(df_data['Fare_'+str(i)+'int_Code'], df_data['Pclass']))
    
    # Plotting
    sns.factorplot(x='Fare_'+str(i)+'int_Code', y="Survived", data=df_data, kind='bar')
    plt.yticks(np.arange(0, 1.25, step=0.25))
# Out:
# Pclass            1    2    3
# Fare_1int_Code
# 0               323  277  709
# Pclass            1    2    3
# Fare_2int_Code
# 0                 8  134  516
# 1               315  143  193
# Pclass            1    2    3
# Fare_3int_Code
# 0                 8    6  441
# 1                14  211  203
# 2               301   60   65
# Pclass            1    2    3
# Fare_4int_Code
# 0                 8    6  324
# 1                 0  128  192
# 2                77  104  147
# 3               238   39   46
# Pclass            1    2    3
# Fare_5int_Code
# 0                 8    6  262
# 1                 0   36  218
# 2                 0  124  131
# 3                95   99   71
# 4               220   12   27
# Pclass            1    2    3
# Fare_6int_Code
# 0                 8    6  223
# 1                 0    0  218
# 2                 0  128   75
# 3                14   83  128
# 4               118   48   46
# 5               183   12   19
# Pclass            1   2    3
# Fare_7int_Code
# 0                 8   6  197
# 1                 0   0  211
# 2                 0  53   86
# 3                 0  91   97
# 4                52  81   53
# 5               100  34   54
# 6               163  12   11
# Pclass            1    2    3
# Fare_8int_Code
# 0                 8    6  197
# 1                 0    0  127
# 2                 0    1  152
# 3                 0  127   40
# 4                 0   41  123
# 5                77   63   24
# 6                89   32   46
# 7               149    7    0
# Pclass            1    2    3
# Fare_9int_Code
# 0                 8    6  132
# 1                 0    0  192
# 2                 0    0  117
# 3                 0  114   53
# 4                 0   27   80
# 5                14   70   70
# 6                74   30   31
# 7                82   30   34
# 8               145    0    0
# Pclass             1   2    3
# Fare_10int_Code
# 0                  8   6  118
# 1                  0   0  144
# 2                  0   0  146
# 3                  0  36   72
# 4                  0  92   36
# 5                  0  32   95
# 6                 41  57   33
# 7                 54  42   38
# 8                 89  12   27
# 9                131   0    0

# %%
df_data
# Out:
#        Age        Cabin Embarked      Fare  \
# 0     22.0          NaN        S    7.2500
# 1     38.0          C85        C   71.2833
# 2     26.0          NaN        S    7.9250
# 3     35.0         C123        S   53.1000
# 4     35.0          NaN        S    8.0500
# 5      NaN          NaN        Q    8.4583
# 6     54.0          E46        S   51.8625
# 7      2.0          NaN        S   21.0750
# 8     27.0          NaN        S   11.1333
# 9     14.0          NaN        C   30.0708
# 10     4.0           G6        S   16.7000
# 11    58.0         C103        S   26.5500
# 12    20.0          NaN        S    8.0500
# 13    39.0          NaN        S   31.2750
# 14    14.0          NaN        S    7.8542
# 15    55.0          NaN        S   16.0000
# 16     2.0          NaN        Q   29.1250
# 17     NaN          NaN        S   13.0000
# 18    31.0          NaN        S   18.0000
# 19     NaN          NaN        C    7.2250
# 20    35.0          NaN        S   26.0000
# 21    34.0          D56        S   13.0000
# 22    15.0          NaN        Q    8.0292
# 23    28.0           A6        S   35.5000
# 24     8.0          NaN        S   21.0750
# 25    38.0          NaN        S   31.3875
# 26     NaN          NaN        C    7.2250
# 27    19.0  C23 C25 C27        S  263.0000
# 28     NaN          NaN        Q    7.8792
# 29     NaN          NaN        S    7.8958
# ...    ...          ...      ...       ...
# 1298       1    male      1  ...               0              1
# 1299       3  female      0  ...               0              0
# 1300       3  female      1  ...               0              0
# 1301       3  female      0  ...               0              0
# 1302       1  female      1  ...               0              1
# 1303       3  female      0  ...               0              0
# 1304       3    male      0  ...               0              0
# 1305       1  female      0  ...               0              1
# 1306       3    male      0  ...               0              0
# 1307       3    male      0  ...               0              0
# 1308       3    male      1  ...               0              1
#
#       Fare_3int_Code Fare_4int_Code Fare_5int_Code Fare_6int_Code  \
# 0                  0              0              0              0
# 1                  2              3              4              5
# 2                  0              1              1              1
# 3                  2              3              4              4
# 4                  0              1              1              1
# 5                  0              1              1              1
# 6                  2              3              4              4
# 7                  1              2              2              3
# 8                  1              1              2              2
# 9                  2              2              3              4
# 10                 1              2              2              3
# 11                 2              2              3              4
# 12                 0              1              1              1
# 13                 2              2              3              4
# 14                 0              0              0              1
# 15                 1              2              2              3
# 16                 2              2              3              4
# 17                 1              1              2              2
# 18                 1              2              2              3
# 19                 0              0              0              0
# 20                 1              2              3              3
# 21                 1              1              2              2
# 22                 0              1              1              1
# 23                 2              3              3              4
# 24                 1              2              2              3
# 25                 2              3              3              4
# 26                 0              0              0              0
# 27                 2              3              4              5
# 28                 0              0              1              1
# 29                 0              0              1              1
# ...              ...            ...            ...            ...
# 1279               0              0              0              0
# 1280               1              2              2              3
# 1281               2              3              4              5
# 1282               2              3              3              4
# 1283               1              2              2              3
# 1284               1              1              1              2
# 1285               1              2              3              3
# 1286               2              3              4              5
# 1287               0              0              0              0
# 1288               2              3              4              5
# 1289               0              0              0              0
# 1290               0              0              0              0
# 1291               2              3              4              5
# 1292               1              2              2              3
# 1293               2              3              4              5
# 1294               2              3              4              4
# 1295               2              2              3              4
# 1296               1              1              2              2
# 1297               1              1              1              2
# 1298               2              3              4              5
# 1299               0              0              0              0
# 1300               1              1              2              2
# 1301               0              0              0              0
# 1302               2              3              4              5
# 1303               0              0              0              0
# 1304               0              1              1              1
# 1305               2              3              4              5
# 1306               0              0              0              0
# 1307               0              1              1              1
# 1308               1              2              3              3
#
#      Fare_7int_Code Fare_8int_Code Fare_9int_Code Fare_10int_Code
# 0                 0              0              0               0
# 1                 6              7              7               8
# 2                 1              2              2               2
# 3                 5              6              7               8
# 4                 1              2              2               2
# 5                 2              2              2               3
# 6                 5              6              7               8
# 7                 4              4              5               5
# 8                 2              3              3               4
# 9                 5              5              6               7
# 10                3              4              5               5
# 11                4              5              6               6
# 12                1              2              2               2
# 13                5              5              6               7
# 14                1              1              1               1
# 15                3              4              4               5
# 16                5              5              6               7
# 17                3              3              3               4
# 18                3              4              5               5
# 19                0              0              0               0
# 20                4              5              5               6
# 21                3              3              3               4
# 22                1              2              2               2
# 23                5              6              6               7
# 24                4              4              5               5
# 25                5              6              6               7
# 26                0              0              0               0
# 27                6              7              8               9
# 28                1              1              1               2
# 29                1              1              1               2
# ...             ...            ...            ...             ...
# 1279              0              0              1               1
# 1280              4              4              5               5
# 1281              6              7              8               9
# 1282              5              6              7               7
# 1283              4              4              5               5
# 1284              2              3              3               3
# 1285              4              4              5               6
# 1286              6              6              7               8
# 1287              0              0              0               0
# 1288              6              7              8               9
# 1289              1              1              1               1
# 1290              0              0              1               1
# 1291              6              7              8               9
# 1292              4              4              5               5
# 1293              5              6              7               8
# 1294              5              6              7               8
# 1295              4              5              6               7
# 1296              3              3              4               4
# 1297              2              3              3               3
# 1298              6              7              8               9
# 1299              0              0              0               1
# 1300              3              3              4               4
# 1301              0              0              1               1
# 1302              6              7              8               9
# 1303              1              1              1               1
# 1304              1              2              2               2
# 1305              6              7              8               9
# 1306              0              0              0               0
# 1307              1              2              2               2
# 1308              4              4              5               6
#
# [1309 rows x 34 columns]

# %% [markdown]
# #### The contribution of variable Fare with n intervals(X) on Survived(Y)
# + Choose 5,6,8,9,10 intervals for further testing

# %%
# Data slicing
df_train = df_data[:len(df_train)]
df_test = df_data[len(df_train):]

# Training features selection
for i in range(1,11):
    X_train = df_train['Fare_'+str(i)+'int_Code'].to_frame()  # transform series into dataframe
    Y_train = df_train['Survived']

    # Model training
    model_3_test = RandomForestClassifier(random_state=0, n_estimators=250, min_samples_split=20, oob_score=True)
    model_3_test.fit(X_train, Y_train)    
    print('oob score of '+str(i)+' intervals : %.5f' %(model_3_test.oob_score_))
# Out:
# oob score of 1 intervals : 0.61616
# oob score of 2 intervals : 0.63412
# oob score of 3 intervals : 0.65544
# oob score of 4 intervals : 0.66442
# oob score of 5 intervals : 0.67228
# oob score of 6 intervals : 0.67789
# oob score of 7 intervals : 0.66330
# oob score of 8 intervals : 0.66891
# oob score of 9 intervals : 0.67340
# oob score of 10 intervals : 0.67452

# %% [markdown]
# #### The contribution of variable Sex(X1), Pclass(X2), Fare with 5,6,8,9,10 intervals(X3) on Survived(Y)
# + Slicing into 5 intervals returns best oob and lb score

# %%
intervals = [5, 6, 8, 9, 10]
lb_score = [0.79425, 0.77033, 0.78947, 0.77990, 0.76555]
j = 0

# Training features selection
for i in intervals:
    X = df_train[['Sex_Code', 'Pclass', 'Fare_'+str(i)+'int_Code']]
    Y = df_train['Survived']

    # Model training
    model_3 = RandomForestClassifier(random_state=0, n_estimators=250, min_samples_split=20, oob_score=True)
    model_3.fit(X, Y)
    print('Out-Of-Bag(oob) score with '+str(i)+' intervals: %.5f' %(model_3.oob_score_), ', lb score : '+str(lb_score[j]))
    j += 1
    
# Export to csv
    # Training features selection
    X_test = df_test[['Sex_Code', 'Pclass', 'Fare_'+str(i)+'int_Code']]

    # Predict by model
    model_3_prediction = model_3.predict(X_test)
    submit_3 = pd.DataFrame({'PassengerId': df_test['PassengerId'], 'Survived': model_3_prediction.astype(int)})
    submit_3.to_csv('Model_3_'+str(i)+'int.csv', index=False)
# Out:
# Out-Of-Bag(oob) score with 5 intervals: 0.81033 , lb score : 0.79425
# Out-Of-Bag(oob) score with 6 intervals: 0.79237 , lb score : 0.77033
# Out-Of-Bag(oob) score with 8 intervals: 0.81033 , lb score : 0.78947
# Out-Of-Bag(oob) score with 9 intervals: 0.78788 , lb score : 0.7799
# Out-Of-Bag(oob) score with 10 intervals: 0.80135 , lb score : 0.76555

# %% [markdown]
# #### Export to CSV

# %%
# Data processing
for i in range(1, 11):
    if i != 5:
        df_data = df_data.drop(['Fare_'+str(i)+'int', 'Fare_'+str(i)+'int_Code'], axis=1)  # delete useless features
df_data.columns
# Out:
# Index(['Age', 'Cabin', 'Embarked', 'Fare', 'Name', 'Parch', 'PassengerId',
#        'Pclass', 'Sex', 'SibSp', 'Survived', 'Ticket', 'Sex_Code', 'surname',
#        'Fare_5int', 'Fare_5int_Code'],
#       dtype='object')

# %%
# Training features selection
X_test = df_test[['Sex_Code', 'Pclass', 'Fare_5int_Code']]

# Predict by model
model_3_prediction = model_3.predict(X_test)
submit_3 = pd.DataFrame({'PassengerId': df_test['PassengerId'], 'Survived': model_3_prediction.astype(int)})
submit_3.to_csv('Model_3.csv', index=False)

# %% [markdown]
# ### 4. Survival rate vs Ticket Connection
# + Interpretation: Some people share same ticket, thus, there might be some relationship between these people. If anyone survived in this group, the other people in this group could possibly survive.
# + LB: 0.80382, CV: 0.82155

# %% [markdown]
# #### Feature analysis

# %%
# Observe on Ticket parameter
df_train['Ticket'].describe()
# Out:
# count          891
# unique         681
# top       CA. 2343
# freq             7
# Name: Ticket, dtype: object

# %%
# Data processing
df_data['Family_size'] = df_data['SibSp'] + df_data['Parch'] + 1  # define Family_size parameter

# Dataset observation
cols = ['Age', 'Name', 'Sex', 'Ticket', 'Pclass', 'Fare', 'Embarked', 'Family_size']
df_data.loc[:, cols]
# Out:
#        Age                                               Name     Sex  \
# 0     22.0                            Braund, Mr. Owen Harris    male
# 1     38.0  Cumings, Mrs. John Bradley (Florence Briggs Th...  female
# 2     26.0                             Heikkinen, Miss. Laina  female
# 3     35.0       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female
# 4     35.0                           Allen, Mr. William Henry    male
# 5      NaN                                   Moran, Mr. James    male
# 6     54.0                            McCarthy, Mr. Timothy J    male
# 7      2.0                     Palsson, Master. Gosta Leonard    male
# 8     27.0  Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)  female
# 9     14.0                Nasser, Mrs. Nicholas (Adele Achem)  female
# 10     4.0                    Sandstrom, Miss. Marguerite Rut  female
# 11    58.0                           Bonnell, Miss. Elizabeth  female
# 12    20.0                     Saundercock, Mr. William Henry    male
# 13    39.0                        Andersson, Mr. Anders Johan    male
# 14    14.0               Vestrom, Miss. Hulda Amanda Adolfina  female
# 15    55.0                   Hewlett, Mrs. (Mary D Kingcome)   female
# 16     2.0                               Rice, Master. Eugene    male
# 17     NaN                       Williams, Mr. Charles Eugene    male
# 18    31.0  Vander Planke, Mrs. Julius (Emelia Maria Vande...  female
# 19     NaN                            Masselmani, Mrs. Fatima  female
# 20    35.0                               Fynney, Mr. Joseph J    male
# 21    34.0                              Beesley, Mr. Lawrence    male
# 22    15.0                        McGowan, Miss. Anna "Annie"  female
# 23    28.0                       Sloper, Mr. William Thompson    male
# 24     8.0                      Palsson, Miss. Torborg Danira  female
# 25    38.0  Asplund, Mrs. Carl Oscar (Selma Augusta Emilia...  
# 1284          C.A. 30769       2   10.5000        S            1
# 1285              315153       3   22.0250        S            5
# 1286               13695       1   60.0000        S            2
# 1287              371109       3    7.2500        Q            1
# 1288               13567       1   79.2000        C            3
# 1289              347065       3    7.7750        S            1
# 1290               21332       3    7.7333        Q            1
# 1291               36928       1  164.8667        S            1
# 1292               28664       2   21.0000        S            2
# 1293              112378       1   59.4000        C            2
# 1294              113059       1   47.1000        S            1
# 1295               17765       1   27.7208        C            2
# 1296       SC/PARIS 2166       2   13.8625        C            1
# 1297               28666       2   10.5000        S            2
# 1298              113503       1  211.5000        C            3
# 1299              334915       3    7.7208        Q            1
# 1300  SOTON/O.Q. 3101315       3   13.7750        S            3
# 1301              365237       3    7.7500        Q            1
# 1302               19928       1   90.0000        Q            2
# 1303              347086       3    7.7750        S            1
# 1304           A.5. 3236       3    8.0500        S            1
# 1305            PC 17758       1  108.9000        C            1
# 1306  SOTON/O.Q. 3101262       3    7.2500        S            1
# 1307              359309       3    8.0500        S            1
# 1308                2668       3   22.3583        C            3
#
# [1309 rows x 8 columns]

# %%
df_duplicate_ticket = pd.DataFrame()

for gruop_key, df_group_data in df_data.groupby('Ticket'):
    # Find people have same tickets
    if (len(df_group_data) > 1):  # record tickets which have shown at least twice
        df_duplicate_ticket = df_duplicate_ticket.append(df_group_data)

# Dataset observation
cols = ['Age', 'Name', 'Sex', 'Ticket', 'Pclass', 'Fare', 'Embarked', 'Family_size']
df_duplicate_ticket.loc[:, cols]
# Out:
#         Age                                               Name     Sex  \
# 257   30.00                               Cherry, Miss. Gladys  female
# 504   16.00                              Maioni, Miss. Roberta  female
# 759   33.00  Rothes, the Countess. of (Lucy Noel Martha Dye...  female
# 262   52.00                                  Taussig, Mr. Emil    male
# 558   39.00             Taussig, Mrs. Emil (Tillie Mandelbaum)  female
# 585   18.00                                Taussig, Miss. Ruth  female
# 110   47.00                     Porter, Mr. Walter Chamberlain    male
# 475     NaN                        Clifford, Mr. George Quincy    male
# 366   60.00   Warren, Mrs. Frank Manley (Anna Sophia Atkinson)  female
# 1127  64.00                           Warren, Mr. Frank Manley    male
# 329   16.00                       Hippach, Miss. Jean Gertrude  female
# 523   44.00    Hippach, Mrs. Louis Albert (Ida Sophia Fischer)  female
# 815     NaN                                   Fry, Mr. Richard    male
# 1263  49.00                            Ismay, Mr. Joseph Bruce    male
# 1259  45.00            Gibson, Mrs. Leonard (Pauline C Boeson)  female
# 1293  22.00                     Gibson, Miss. Dorothy Winifred  female
# 83    28.00                            Carrau, Mr. Francisco M    male
# 1294  17.00                             Carrau, Mr. Jose Pedro    male
# 377   27.00                          Widener, Mr. Harry Elkins    male
# 965   35.00                               Geiger, Miss. Amalie  female
# 966   32.50                                 Keeping, Mr. Edwin    male
# 1109  50.00       Widener, Mrs. George Dunton (Eleanor Elkins)  female
# 1298  50.00                         Widener, Mr. George Dunton    male
# 166     NaN             Chibnall, Mrs. (Edith Martha Bowerman)  female
# 356   22.00                        Bowerman, Miss. Elsie Edith  female
# 54    65.00                     Ostby, Mr. Engelhart Cornelius    male
# 917               113509       1   61.9792        C            2
# 61                113572       1   80.0000      NaN            1
# 829               113572       1   80.0000      NaN            1
# 390               113760       1  120.0000        S            4
# ...                  ...     ...       ...      ...          ...
# 1103        S.O.C. 14879       2   73.5000        S            1
# 1243        S.O.C. 14879       2   73.5000        S            1
# 594          SC/AH 29037       2   26.0000        S            2
# 1010         SC/AH 29037       2   26.0000        S            2
# 432           SC/AH 3085       2   26.0000        S            2
# 921           SC/AH 3085       2   26.0000        S            2
# 361        SC/PARIS 2167       2   27.7208        C            2
# 906        SC/PARIS 2167       2   27.7208        C            2
# 43         SC/Paris 2123       2   41.5792        C            4
# 608        SC/Paris 2123       2   41.5792        C            4
# 685        SC/Paris 2123       2   41.5792        C            4
# 1187       SC/Paris 2123       2   41.5792        C            4
# 1050  SOTON/O.Q. 3101315       3   13.7750        S            3
# 1172  SOTON/O.Q. 3101315       3   13.7750        S            3
# 1300  SOTON/O.Q. 3101315       3   13.7750        S            3
# 142     STON/O2. 3101279       3   15.8500        S            2
# 403     STON/O2. 3101279       3   15.8500        S            2
# 783           W./C. 6607       3   23.4500        S            4
# 888           W./C. 6607       3   23.4500        S            4
# 924           W./C. 6607       3   23.4500        S            4
# 1135          W./C. 6607       3   23.4500        S            4
# 86            W./C. 6608       3   34.3750        S            5
# 147           W./C. 6608       3   34.3750        S            5
# 436           W./C. 6608       3   34.3750        S            5
# 736           W./C. 6608       3   34.3750        S            5
# 1058          W./C. 6608       3   34.3750        S            5
# 92           W.E.P. 5734       1   61.1750        S            2
# 905          W.E.P. 5734       1   61.1750        S            2
# 540            WE/P 5735       1   71.0000        S            3
# 745            WE/P 5735       1   71.0000        S            3
#
# [596 rows x 8 columns]

# %%
df_data['Connected_Survival'] = 0.5 # default

for gruop_key, df_group_data in df_data.groupby('Ticket'):
    if (len(df_group_data) > 1):  # record tickets which have shown at least twice
        for ind, row in df_group_data.iterrows():
            alst_1_surv_in_group = df_group_data.drop(ind)['Survived'].max()  # check if there are at least 1 surviver in a group
            passID = row['PassengerId']
            if (alst_1_surv_in_group == 1.0):  # if there are at least 1 surviver in a group, then set Connected_Survival as 1
                df_data.loc[df_data['PassengerId'] == passID, 'Connected_Survival'] = 1
            elif (alst_1_surv_in_group == 0.0):  # if not, set Connected_Survival as 0
                df_data.loc[df_data['PassengerId'] == passID, 'Connected_Survival'] = 0

# Dataset observation
cols = ['Age', 'Name', 'Sex', 'Ticket', 'Pclass', 'Fare', 'Embarked', 'Family_size', 'Connected_Survival']
df_data.loc[:, cols].head(10)
# Out:
#     Age                                               Name     Sex  \
# 0  22.0                            Braund, Mr. Owen Harris    male
# 1  38.0  Cumings, Mrs. John Bradley (Florence Briggs Th...  female
# 2  26.0                             Heikkinen, Miss. Laina  female
# 3  35.0       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female
# 4  35.0                           Allen, Mr. William Henry    male
# 5   NaN                                   Moran, Mr. James    male
# 6  54.0                            McCarthy, Mr. Timothy J    male
# 7   2.0                     Palsson, Master. Gosta Leonard    male
# 8  27.0  Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)  female
# 9  14.0                Nasser, Mrs. Nicholas (Adele Achem)  female
#
#              Ticket  Pclass     Fare Embarked  Family_size  Connected_Survival
# 0         A/5 21171       3   7.2500        S            2                 0.5
# 1          PC 17599       1  71.2833        C            2                 0.5
# 2  STON/O2. 3101282       3   7.9250        S            1                 0.5
# 3            113803       1  53.1000        S            2                 0.0
# 4            373450       3   8.0500        S            1                 0.5
# 5            330877       3   8.4583        Q            1                 0.5
# 6             17463       1  51.8625        S            1                 0.5
# 7            349909       3  21.0750        S            5                 0.0
# 8            347742       3  11.1333        S            3                 1.0
# 9            237736       2  30.0708        C            2                 0.0

# %% [markdown]
# #### The contribution of variable Ticket Connection(X) on Survived(Y)

# %%
# Data slicing
df_train = df_data[:len(df_train)]
df_test = df_data[len(df_train):]

# Training features selection
X_train = df_train['Connected_Survival'].to_frame()  # transform series into dataframe
Y_train = df_train['Survived']

# Model training
model_4_test = RandomForestClassifier(random_state=0, n_estimators=250, min_samples_split=20, oob_score=True)
model_4_test.fit(X_train, Y_train)
print('Out-Of-Bag(oob) score : %.5f' %(model_4_test.oob_score_))
# Out:
# Out-Of-Bag(oob) score : 0.71942

# %% [markdown]
# #### The contribution of variable Sex(X1), Pclass(X2), Fare with 5 intervals(X3), Ticket Connection(X4) on Survived(Y)

# %%
# Training features selection
X_train = df_train[['Sex_Code', 'Pclass', 'Fare_5int_Code', 'Connected_Survival']]
Y_train = df_train['Survived']

# Model training
model_4 = RandomForestClassifier(random_state=0, n_estimators=250, min_samples_split=20, oob_score=True)
model_4.fit(X_train, Y_train)
print('Out-Of-Bag(oob) score : %.5f' %(model_4.oob_score_))
# Out:
# Out-Of-Bag(oob) score : 0.82155

# %% [markdown]
# #### Export to CSV

# %%
# Training features selection
X_test = df_test[['Sex_Code', 'Pclass', 'Fare_5int_Code', 'Connected_Survival']]

# Predict by model
model_4_prediction = model_4.predict(X_test)
submit_4 = pd.DataFrame({'PassengerId': df_test['PassengerId'], 'Survived': model_4_prediction.astype(int)})
submit_4.to_csv('Model_4.csv', index=False)

# %% [markdown]
# ### 5. Survival rate vs Age

# %% [markdown]
# #### Feature analysis
# + Teens(<16yrs) have higher survival rate
# + LB: 0.82296, CV: 0.84063

# %%
# Plotting
plt.figure(figsize = (16,6))  # enlarge figure size
s = sns.distplot(df_data.loc[df_data.Survived == 1]['Age'].dropna(), kde=False, bins=30, norm_hist=True, label='Survived')
s = sns.distplot(df_data.loc[df_data.Survived == 0]['Age'].dropna(), kde=False, bins=30, norm_hist=True, label='Dead')
s.set_xlabel('Age',fontsize=16)
s.set_ylabel('Intensity',fontsize=16)
s.set_xticks(range(0, 85, 5))
s.legend()

# %%
# Extract name titles
df_data['Name_Title'] = df_data.Name.str.extract(' ([A-Za-z]+)\.', expand=False)  # Extract name by regular expression
display(df_data['Name_Title'].unique())

# Observe the relation between name titles and other parameters
display(df_data.groupby('Name_Title')['Age'].median())
display(pd.crosstab(df_data['Name_Title'], df_data['Sex']).T.style.background_gradient(cmap='summer_r'))
display(pd.crosstab(df_data['Name_Title'], df_data['Survived']).T.style.background_gradient(cmap='summer_r'))
# Out:
# array(['Mr', 'Mrs', 'Miss', 'Master', 'Don', 'Rev', 'Dr', 'Mme', 'Ms',
#                         <td id="T_fab869f4_59b0_11e9_ac06_b870f4a97165row0_col10" class="data row0 col10" >0</td>
#                         <td id="T_fab869f4_59b0_11e9_ac06_b870f4a97165row0_col11" class="data row0 col11" >0</td>
#                         <td id="T_fab869f4_59b0_11e9_ac06_b870f4a97165row0_col12" class="data row0 col12" >436</td>
#                         <td id="T_fab869f4_59b0_11e9_ac06_b870f4a97165row0_col13" class="data row0 col13" >26</td>

# %%
# Merge name titles
df_data['Name_Title'] = df_data['Name_Title'].replace(['Capt', 'Col', 'Don', 'Dr', 'Jonkheer', 'Major',
                                                     'Rev', 'Sir'], 'Elderly_male')
df_data['Name_Title'] = df_data['Name_Title'].replace(['Countess', 'Dona', 'Lady'], 'Mrs')
df_data['Name_Title'] = df_data['Name_Title'].replace(['Mlle', 'Ms','Mme'],'Miss')
display(df_data['Name_Title'].unique())

# Observe the relation between name titles and other parameters
display(df_data.groupby('Name_Title')['Age'].median())
display(pd.crosstab(df_data['Name_Title'], df_data['Sex']).T.style.background_gradient(cmap='summer_r'))
display(pd.crosstab(df_data['Name_Title'], df_data['Survived']).T.style.background_gradient(cmap='summer_r'))

# Dataset observation
cols = ['Age', 'Name', 'Sex', 'Name_Title']
df_data.loc[:, cols]
# Out:
# array(['Mr', 'Mrs', 'Miss', 'Master', 'Elderly_male'], dtype=object)
# Name_Title
# Elderly_male    49.0
# Master           4.0
# Miss            22.0
# Mr              29.0
# Mrs             36.0
# Name: Age, dtype: float64
# <style  type="text/css" >
#     #T_fac4eb34_59b0_11e9_9b1d_b870f4a97165row0_col0 {
#             background-color:  #ffff66;
#             color:  #000000;
#         }    #T_fac4eb34_59b0_11e9_9b1d_b870f4a97165row0_col1 {
#             background-color:  #ffff66;
#             color:  #000000;
#         }    #T_fac4eb34_59b0_11e9_9b1d_b870f4a97165row0_col2 {
#             background-color:  #008066;
#             color:  #f1f1f1;
#         }    #T_fac4eb34_59b0_11e9_9b1d_b870f4a97165row0_col3 {
#             background-color:  #ffff66;
#             color:  #000000;
#         }    #T_fac4eb34_59b0_11e9_9b1d_b870f4a97165row0_col4 {
#             background-color:  #008066;
#             color:  #f1f1f1;
#         }    #T_fac4eb34_59b0_11e9_9b1d_b870f4a97165row1_col0 {
#             background-color:  #008066;
#             color:  #f1f1f1;
#         }    #T_fac4eb34_59b0_11e9_9b1d_b870f4a97165row1_col1 {
#             background-color:  #008066;
#             color:  #f1f1f1;
#         }    #T_fac4eb34_59b0_11e9_9b1d_b870f4a97165row1_col2 {
#             background-color:  #ffff66;
#             color:  #000000;
#         }    #T_fac4eb34_59b0_11e9_9b1d_b870f4a97165row1_col3 {
#             background-color:  #008066;
#             color:  #f1f1f1;
#         }    #T_fac4eb34_59b0_11e9_9b1d_b870f4a97165row1_col4 {
#             background-color:  #ffff66;
#             color:  #000000;
#         }</style><table id="T_fac4eb34_59b0_11e9_9b1d_b870f4a97165" ><thead>    <tr>        <th class="index_name level0" >Name_Title</th>        <th class="col_heading level0 col0" >Elderly_male</th>        <th class="col_heading level0 col1" >Master</th>        <th class="col_heading level0 col2" >Miss</th>        <th class="col_heading level0 col3" >Mr</th>        <th class="col_heading level0 col4" >Mrs</th>    </tr>    <tr>        <th class="index_name level0" >Sex</th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_fac4eb34_59b0_11e9_9b1d_b870f4a97165level0_row0" class="row_heading level0 row0" >female</th>
#                         <td id="T_fac4eb34_59b0_11e9_9b1d_b870f4a97165row0_col0" class="data row0 col0" >1</td>
#                         <td id="T_fac4eb34_59b0_11e9_9b1d_b870f4a97165row0_col1" class="data row0 col1" >0</td>
#                         <td id="T_fac4eb34_59b0_11e9_9b1d_b870f4a97165row0_col2" class="data row0 col2" >265</td>
#                         <td id="T_fac4eb34_59b0_11e9_9b1d_b870f4a97165row0_col3" class="data row0 col3" >0</td>
#                         <td id="T
# 1307   NaN                                Ware, Mr. Frederick    male
# 1308   NaN                           Peter, Master. Michael J    male
#
#      Name_Title
# 0            Mr
# 1           Mrs
# 2          Miss
# 3           Mrs
# 4            Mr
# 5            Mr
# 6            Mr
# 7        Master
# 8           Mrs
# 9           Mrs
# 10         Miss
# 11         Miss
# 12           Mr
# 13           Mr
# 14         Miss
# 15          Mrs
# 16       Master
# 17           Mr
# 18          Mrs
# 19          Mrs
# 20           Mr
# 21           Mr
# 22         Miss
# 23           Mr
# 24         Miss
# 25          Mrs
# 26           Mr
# 27           Mr
# 28         Miss
# 29           Mr
# ...         ...
# 1279         Mr
# 1280     Master
# 1281         Mr
# 1282        Mrs
# 1283     Master
# 1284         Mr
# 1285         Mr
# 1286        Mrs
# 1287         Mr
# 1288        Mrs
# 1289         Mr
# 1290         Mr
# 1291       Miss
# 1292         Mr
# 1293       Miss
# 1294         Mr
# 1295         Mr
# 1296         Mr
# 1297         Mr
# 1298         Mr
# 1299       Miss
# 1300       Miss
# 1301       Miss
# 1302        Mrs
# 1303       Miss
# 1304         Mr
# 1305        Mrs
# 1306         Mr
# 1307         Mr
# 1308     Master
#
# [1309 rows x 4 columns]

# %%
# Make dictionary
Pred_Age_by_NameTitle = df_data.groupby('Name_Title')['Age'].median().values
Name_Title = df_data.groupby('Name_Title')['Age'].groups.keys()
dic = dict(zip(Name_Title, Pred_Age_by_NameTitle))
display(dic)

# Fill missing age
df_data['Pred_Age_by_NameTitle'] = df_data['Age']
df_data['Pred_Age_by_NameTitle'] = df_data['Pred_Age_by_NameTitle'].fillna(df_data['Name_Title'].apply(lambda x: dic.get(x)))
df_data['Pred_Age_by_NameTitle'] = df_data['Pred_Age_by_NameTitle'].astype('int')

# Dataset observation
df_data.info()
cols = ['Age', 'Name', 'Sex', 'Name_Title', 'Pred_Age_by_NameTitle']
df_data.loc[:, cols]
# Out:
# {'Elderly_male': 49.0, 'Master': 4.0, 'Miss': 22.0, 'Mr': 29.0, 'Mrs': 36.0}
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1309 entries, 0 to 1308
# Data columns (total 20 columns):
# Age                      1046 non-null float64
# Cabin                    295 non-null object
# Embarked                 1307 non-null object
# Fare                     1309 non-null float64
# Name                     1309 non-null object
# Parch                    1309 non-null int64
# PassengerId              1309 non-null int64
# Pclass                   1309 non-null int64
# Sex                      1309 non-null object
# SibSp                    1309 non-null int64
# Survived                 891 non-null float64
# Ticket                   1309 non-null object
# Sex_Code                 1309 non-null int64
# surname                  1309 non-null object
# Fare_5int                1309 non-null category
# Fare_5int_Code           1309 non-null int32
# Family_size              1309 non-null int64
# Connected_Survival       1309 non-null float64
# Name_Title               1309 non-null object
# Pred_Age_by_NameTitle    1309 non-null int32
# dtypes: category(1), float64(4), int32(2), int64(6), object(7)
# memory usage: 185.5+ KB
#        Age                                               Name     Sex  \
# 0     22.0                            Braund, Mr. Owen Harris    male
# 1     38.0  Cumings, Mrs. John Bradley (Florence Briggs Th...  female
# 2     26.0                             Heikkinen, Miss. Laina  female
# 3     35.0       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female
# 4     35.0                           Allen, Mr. William Henry    male
# 5      NaN                                   Moran, Mr. James    male
# 6     54.0                            McCarthy, Mr. Timothy J    male
# 7      2.0                     Palsson, Master. Gosta Leonard    male
# 8     27.0  Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)  
# 4            Mr                     35
# 5            Mr                     29
# 6            Mr                     54
# 7        Master                      2
# 8           Mrs                     27
# 9           Mrs                     14
# 10         Miss                      4
# 11         Miss                     58
# 12           Mr                     20
# 13           Mr                     39
# 14         Miss                     14
# 15          Mrs                     55
# 16       Master                      2
# 17           Mr                     29
# 18          Mrs                     31
# 19          Mrs                     36
# 20           Mr                     35
# 21           Mr                     34
# 22         Miss                     15
# 23           Mr                     28
# 24         Miss                      8
# 25          Mrs                     38
# 26           Mr                     29
# 27           Mr                     19
# 28         Miss                     22
# 29           Mr                     29
# ...         ...                    ...
# 1279         Mr                     21
# 1280     Master                      6
# 1281         Mr                     23
# 1282        Mrs                     51
# 1283     Master                     13
# 1284         Mr                     47
# 1285         Mr                     29
# 1286        Mrs                     18
# 1287         Mr                     24
# 1288        Mrs                     48
# 1289         Mr                     22
# 1290         Mr                     31
# 1291       Miss                     30
# 1292         Mr                     38
# 1293       Miss                     22
# 1294         Mr                     17
# 1295         Mr                     43
# 1296         Mr                     20
# 1297         Mr                     23
# 1298         Mr                     50
# 1299       Miss                     22
# 1300       Miss                      3
# 1301       Miss                     22
# 1302        Mrs                     37
# 1303       Miss                     28
# 1304         Mr                     29
# 1305        Mrs                     39
# 1306         Mr                     38
# 1307         Mr                     29
# 1308     Master                      4
#
# [1309 rows x 5 columns]

# %%
df_data['Kid'] = ((df_data['Pred_Age_by_NameTitle']) < 16.0) * 1

# Dataset observation
cols =  ['Age', 'Name', 'Sex', 'Name_Title', 'Pred_Age_by_NameTitle', 'Kid']
df_data.loc[:, cols].head(10)
# Out:
#     Age                                               Name     Sex Name_Title  \
# 0  22.0                            Braund, Mr. Owen Harris    male         Mr
# 1  38.0  Cumings, Mrs. John Bradley (Florence Briggs Th...  female        Mrs
# 2  26.0                             Heikkinen, Miss. Laina  female       Miss
# 3  35.0       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female        Mrs
# 4  35.0                           Allen, Mr. William Henry    male         Mr
# 5   NaN                                   Moran, Mr. James    male         Mr
# 6  54.0                            McCarthy, Mr. Timothy J    male         Mr
# 7   2.0                     Palsson, Master. Gosta Leonard    male     Master
# 8  27.0  Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)  female        Mrs
# 9  14.0                Nasser, Mrs. Nicholas (Adele Achem)  female        Mrs
#
#    Pred_Age_by_NameTitle  Kid
# 0                     22    0
# 1                     38    0
# 2                     26    0
# 3                     35    0
# 4                     35    0
# 5                     29    0
# 6                     54    0
# 7                      2    1
# 8                     27    0
# 9                     14    1

# %% [markdown]
# #### The contribution of variable Age(X) on Survived(Y)

# %%
# Data slicing
df_train = df_data[:len(df_train)]
df_test = df_data[len(df_train):]

# Training features selection
X_train = df_train['Kid'].to_frame()  # transform series into dataframe
Y_train = df_train['Survived']

# Model training
model_5_test = RandomForestClassifier(random_state=0, n_estimators=250, min_samples_split=20, oob_score=True)
model_5_test.fit(X_train, Y_train)
print('Out-Of-Bag(oob) score : %.5f' %(model_5_test.oob_score_))
# Out:
# Out-Of-Bag(oob) score : 0.63300

# %% [markdown]
# #### The contribution of variable Sex(X1), Pclass(X2), Fare with 5 intervals(X3), Ticket Connection(X4), Age(X5) on Survived(Y)

# %%
# Training features selection
X_train = df_train[['Sex_Code', 'Pclass', 'Fare_5int_Code', 'Connected_Survival', 'Kid']]
Y_train = df_train['Survived']

# Model training
model_5 = RandomForestClassifier(random_state=0, n_estimators=250, min_samples_split=20, oob_score=True)
model_5.fit(X_train, Y_train)
print('Out-Of-Bag(oob) score : %.5f' %(model_5.oob_score_))
# Out:
# Out-Of-Bag(oob) score : 0.84063

# %% [markdown]
# #### Export to CSV

# %%
# Training features selection
X_test = df_test[['Sex_Code', 'Pclass', 'Fare_5int_Code', 'Connected_Survival', 'Kid']]

# Predict by model
model_5_prediction = model_5.predict(X_test)
submit_5 = pd.DataFrame({'PassengerId': df_test['PassengerId'], 'Survived': model_5_prediction.astype(int)})
submit_5.to_csv('Model_5.csv', index=False)

# %% [markdown]
# ### Hyper-parameters searching
# + LB: 0.82775, CV: 0.83951

# %%
# Parameters setup
kfold = StratifiedKFold(n_splits=5)
random_state = 0

# Training features selection
X_train = df_train[['Sex_Code', 'Pclass', 'Fare_5int_Code', 'Connected_Survival', 'Kid']]
Y_train = df_train['Survived']
X_test = df_test[['Sex_Code', 'Pclass', 'Fare_5int_Code', 'Connected_Survival', 'Kid']]

# %%
# RandomForestClassifier
rfc = RandomForestClassifier(random_state=random_state)

# Model training and hyper-parameters turning
rfc_param_grid = {"max_depth": [None],
                  "min_samples_split": [2, 10, 20, 50, 100],
                  "min_samples_leaf": [1, 3, 5],
                  "bootstrap": [False],
                  "n_estimators": [100, 250, 800, 1000],
                  "criterion": ['entropy','gini']}

gsrfc = GridSearchCV(rfc, param_grid=rfc_param_grid, cv=kfold, scoring='accuracy', n_jobs=-1, verbose=1)
gsrfc.fit(X_train, Y_train)
gsrfc_best = gsrfc.best_estimator_

# Best score
print('Best CV score of RandomForestClassifier : %.5f' %(gsrfc.best_score_))

# Predict by model
gsrfc_prediction = gsrfc.predict(X_test)
submit_gsrfc = pd.DataFrame({'PassengerId': df_test['PassengerId'], 'Survived': gsrfc_prediction.astype(int)})
submit_gsrfc.to_csv('Model_RandomForestClassifier.csv', index=False)

# %% [markdown]
# ## 3.Failed attempts

# %% [markdown]
# ### Performance on other models with hyper-parameters searching
# We chose **RandomForestClassifier, SVC, Adaboost, ExtraTreesClassifier, GradientBoostingClassifier, XGBClassifier** from the following candidates
# + **RandomForestClassifier(LB: 0.82775, CV: 0.83951)**
# + **SVC(LB: 0.79904, CV: 0.84624)**
# + DecisionTreeClassifier
# + **Adaboost(LB: 0.80382, CV: 0.84512)**
# + **ExtraTreesClassifier(LB: , CV: 0.84512)**
# + **GradientBoostingClassifier(LB: , CV: 0.82155)**
# + MLPClassifier
# + KNeighborsClassifie
# + LogisticRegression
# + LinearDiscriminantAnalysis
# + **XGBClassifier(LB: 0.81818, CV: 0.84624)**

# %%
# Import Machine Learning Library Packages
from sklearn.svm import SVC
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import AdaBoostClassifier, GradientBoostingClassifier, ExtraTreesClassifier, VotingClassifier
from sklearn.neural_network import MLPClassifier
from sklearn.neighbors import KNeighborsClassifier
from sklearn.linear_model import LogisticRegression
from sklearn.discriminant_analysis import LinearDiscriminantAnalysis
from xgboost import XGBClassifier
from sklearn.feature_selection import RFECV

# %% [markdown]
# **<font color=black size=3>Choose potential candidates</font>**

# %%
# Modeling step Test differents algorithms 
classifiers = []
classifiers.append(RandomForestClassifier(random_state=random_state))
classifiers.append(SVC(random_state=random_state))
classifiers.append(DecisionTreeClassifier(random_state=random_state))
classifiers.append(AdaBoostClassifier(DecisionTreeClassifier(random_state=random_state),random_state=random_state,learning_rate=0.1))
classifiers.append(ExtraTreesClassifier(random_state=random_state))
classifiers.append(GradientBoostingClassifier(random_state=random_state))
classifiers.append(MLPClassifier(random_state=random_state))
classifiers.append(KNeighborsClassifier())
classifiers.append(LogisticRegression(random_state = random_state))
classifiers.append(LinearDiscriminantAnalysis())
classifiers.append(XGBClassifier(random_state = random_state))


cv_results = []
for classifier in classifiers :
    cv_results.append(cross_val_score(classifier, X_train, Y_train, scoring = "accuracy", cv = kfold, n_jobs=-1))

cv_means = []
cv_std = []
for cv_result in cv_results:
    cv_means.append(cv_result.mean())
    cv_std.append(cv_result.std())

cv_res = pd.DataFrame({"CrossValMeans":cv_means,
                       "CrossValerrors": cv_std,
                       "Algorithm":["RandomForest", "SVC", "DecisionTree", "AdaBoost", "ExtraTrees",
                                    "GradientBoosting", "MultipleLayerPerceptron", "KNeighboors", 
                                    "LogisticRegression", "LinearDiscriminantAnalysis", "XGB"]})

g = sns.barplot("CrossValMeans","Algorithm",data = cv_res, palette="Set3",orient = "h",**{'xerr':cv_std})
g.set_xlabel("Mean Accuracy")
g = g.set_title("Cross validation scores")

# %%
# SVC
svc = SVC(probability=True)

# Model training and hyper-parameters turning
svc_param_grid = {'kernel': ['rbf'], 
                  'gamma': [ 0.001, 0.01, 0.1, 1],
                  'C': [1, 10, 50, 100, 200, 300, 500, 1000]}

gssvc = GridSearchCV(svc, param_grid=svc_param_grid, cv=kfold, scoring="accuracy", n_jobs=-1, verbose=1)
gssvc.fit(X_train, Y_train)
gssvc_best = gssvc.best_estimator_

# Best score
print('Best CV score of SVC : %.5f' %(gssvc.best_score_))

# Predict by model
gssvc_prediction = gssvc.predict(X_test)
submit_gssvc = pd.DataFrame({'PassengerId': df_test['PassengerId'], 'Survived': gssvc_prediction.astype(int)})
submit_gssvc.to_csv('Model_SVC.csv', index=False)
# Out:
# Fitting 5 folds for each of 32 candidates, totalling 160 fits
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 4 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  42 tasks      | elapsed:    1.8s
# Best CV score of SVC : 0.84624
# [Parallel(n_jobs=-1)]: Done 160 out of 160 | elapsed:   10.2s finished

# %%
# AdaBoostClassifier
ada = AdaBoostClassifier(DecisionTreeClassifier(), random_state=random_state)

# Model training and hyper-parameters turning
ada_param_grid = {"base_estimator__criterion": ["gini", "entropy"],
                  "base_estimator__splitter": ["best", "random"],
                  "algorithm": ["SAMME","SAMME.R"],
                  "n_estimators": [1, 2, 3, 5, 8, 10],
                  "learning_rate": [0.0001, 0.001, 0.01, 0.1, 0.2, 0.3,1.5]}

gsada = GridSearchCV(ada, param_grid=ada_param_grid, cv=kfold, scoring="accuracy", n_jobs=-1, verbose=1)
gsada.fit(X_train, Y_train)
gsada_best = gsada.best_estimator_

# Best score
print('Best CV score of Adaboost : %.5f' %(gsada.best_score_))

# Predict by model
gsada_prediction = gsada.predict(X_test)
submit_gsada = pd.DataFrame({'PassengerId': df_test['PassengerId'], 'Survived': gsada_prediction.astype(int)})
submit_gsada.to_csv('Model_AdaBoostClassifier.csv', index=False)
# Out:
# Fitting 5 folds for each of 336 candidates, totalling 1680 fits
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 4 concurrent workers.
# [Parallel(n_jobs=-1)]: Done 348 tasks      | elapsed:    3.4s
# Best CV score of Adaboost : 0.84512
# [Parallel(n_jobs=-1)]: Done 1680 out of 1680 | elapsed:   17.0s finished

# %%
# ExtraTreesClassifier 
exttc = ExtraTreesClassifier()

# Model training and hyper-parameters turning
exttc_param_grid = {"max_depth": [None],
                    "max_features": [1, 3, 5],
                    "min_samples_split": [2, 3, 10],
                    "min_samples_leaf": [1, 3, 10],
                    "bootstrap": [False],
                    "n_estimators": [100, 300],
                    "criterion": ["gini"]}

gsexttc = GridSearchCV(exttc, param_grid=exttc_param_grid, cv=kfold, scoring="accuracy", n_jobs=-1, verbose=1)
gsexttc.fit(X_train, Y_train)
gsexttc_best = gsexttc.best_estimator_

# Best score
print('Best CV score of ExtraTreesClassifier : %.5f' %(gsexttc.best_score_))

# Predict by model
gsexttc_prediction = gsexttc.predict(X_test)
submit_gsexttc = pd.DataFrame({'PassengerId': df_test['PassengerId'], 'Survived': gsexttc_prediction.astype(int)})
submit_gsexttc.to_csv('Model_ExtraTreesClassifier.csv', index=False)
# Out:
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 4 concurrent workers.
# Fitting 5 folds for each of 54 candidates, totalling 270 fits
# [Parallel(n_jobs=-1)]: Done  42 tasks      | elapsed:    6.3s
# [Parallel(n_jobs=-1)]: Done 192 tasks      | elapsed:   27.7s
# Best CV score of ExtraTreesClassifier : 0.84624
# [Parallel(n_jobs=-1)]: Done 270 out of 270 | elapsed:   39.6s finished

# %%
# GradientBoostingClassifier
gbc = GradientBoostingClassifier()

# Model training and hyper-parameters turning
gbc_param_grid = {'loss': ["deviance"],
                  'n_estimators' : [100, 200, 300],
                  'learning_rate': [0.1, 0.05, 0.01],
                  'max_depth': [4, 8],
                  'min_samples_leaf': [100, 150],
                  'max_features': [0.3, 0.1]}

gsgbc = GridSearchCV(gbc, param_grid=gbc_param_grid, cv=kfold, scoring="accuracy", n_jobs=-1, verbose=1)
gsgbc.fit(X_train, Y_train)
gsgbc_best = gsgbc.best_estimator_

# Best score
print('Best CV score of ExtraTreesClassifier : %.5f' %(gsgbc.best_score_))

# Predict by model
gsgbc_prediction = gsgbc.predict(X_test)
submit_gsgbc = pd.DataFrame({'PassengerId': df_test['PassengerId'], 'Survived': gsgbc_prediction.astype(int)})
submit_gsgbc.to_csv('Model_GradientBoostingClassifier.csv', index=False)
# Out:
# Fitting 5 folds for each of 72 candidates, totalling 360 fits
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 4 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  76 tasks      | elapsed:    4.4s
# [Parallel(n_jobs=-1)]: Done 360 out of 360 | elapsed:   21.9s finished
# Best CV score of ExtraTreesClassifier : 0.82267

# %%
# XGBClassifier
xgbc = XGBClassifier(random_state=random_state)

# Model training and hyper-parameters turning
xgbc_param_grid = {'objective':['binary:logistic'],
                  'learning_rate': [0.2, 0.1, 0.05, 0.001], #so called `eta` value
                  'max_depth': [1, 2, 5, 8, 10],
                  'min_child_weight': [1, 2, 5, 8, 10],
                  'subsample': [0.8],
                  'colsample_bytree': [0.7],
                  'n_estimators': [10, 50, 100, 200, 500, 1000], #number of trees, change it to 1000 for better results
                  'seed': [0]}

gsxgbc = GridSearchCV(xgbc, param_grid=xgbc_param_grid, cv=kfold, scoring="accuracy", n_jobs=-1, verbose=1)
gsxgbc.fit(X_train, Y_train)
gsxgbc_best = gsxgbc.best_estimator_

# Best score
print('Best CV score of XGBClassifier : %.5f' %(gsxgbc.best_score_))


# Predict by model
gsxgbc_prediction = gsxgbc.predict(X_test)
submit_gsxgbc = pd.DataFrame({'PassengerId': df_test['PassengerId'], 'Survived': gsxgbc_prediction.astype(int)})
submit_gsxgbc.to_csv('Model_XGBClassifier.csv', index=False)
# Out:
# Fitting 5 folds for each of 600 candidates, totalling 3000 fits
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 4 concurrent workers.
# [Parallel(n_jobs=-1)]: Done 144 tasks      | elapsed:    6.9s
# [Parallel(n_jobs=-1)]: Done 443 tasks      | elapsed:   28.9s
# [Parallel(n_jobs=-1)]: Done 693 tasks      | elapsed:   53.8s
# [Parallel(n_jobs=-1)]: Done 1043 tasks      | elapsed:  1.3min
# [Parallel(n_jobs=-1)]: Done 1493 tasks      | elapsed:  2.1min
# [Parallel(n_jobs=-1)]: Done 2173 tasks      | elapsed:  3.0min
# [Parallel(n_jobs=-1)]: Done 2823 tasks      | elapsed:  4.0min
# [Parallel(n_jobs=-1)]: Done 3000 out of 3000 | elapsed:  4.3min finished
# Best CV score of XGBClassifier : 0.84624

# %% [markdown]
# ### Model ensembling

# %%
votingc = VotingClassifier(estimators=[('rfc', gsrfc_best), 
                                       ('extc', gsexttc_best), 
                                       ('svc', gssvc_best), 
                                       ('adac',ada_best), 
                                       ('gbc',gsgbc_best), 
                                       ('xgbc',gsxgbc_best)], voting='soft', n_jobs=-1)

votingc = votingc.fit(X_train, Y_train)
votingc_prediction = pd.Series(votingc.predict(X_test), name="Survived")
submit_votingc = pd.DataFrame({'PassengerId': df_test['PassengerId'], 'Survived': np.array(votingc_prediction).astype(int)})
submit_votingc.to_csv("Model_VotingClassifier.csv",index=False)

# %% [markdown]
# ### Review on failure

# %%
nrows = 5
ncols = 1
fig, axes = plt.subplots(nrows = nrows, ncols = ncols, sharex="all", figsize=(10,25))

names_classifiers = [("RandomForestClassifier", gsrfc_best),
                     ("AdaBoostClassifier", gsada_best),
                     ("ExtraTreesClassifier", gsexttc_best),
                     ("GradientBoostingClassifier", gsgbc_best),
                     ("XGBClassifier", gsxgbc_best)]

nclassifier = 0
for row in range(nrows):
    name = names_classifiers[nclassifier][0]
    classifier = names_classifiers[nclassifier][1]
    indices = np.argsort(classifier.feature_importances_)[::-1][:40]
    g = sns.barplot(y=X_train.columns[indices][:40], x=classifier.feature_importances_[indices][:40] , orient='h',ax=axes[row])
    g.set_xlabel("Relative importance",fontsize=15)
    g.set_ylabel("Features",fontsize=15)
    g.tick_params(labelsize=12)
    g.set_title(name + " feature importance")
    nclassifier += 1

# %%
test_Survived_rfc = pd.Series(gsrfc_best.predict(X_test), name="RFC")
test_Survived_exttc = pd.Series(gsexttc_best.predict(X_test), name="ExtC")
test_Survived_svc = pd.Series(gssvc_best.predict(X_test), name="SVC")
test_Survived_ada = pd.Series(ada_best.predict(X_test), name="Ada")
test_Survived_gbc = pd.Series(gsgbc_best.predict(X_test), name="GBC")
test_Survived_xgbc = pd.Series(gsxgbc_best.predict(X_test), name="XGBC")


# Concatenate all classifier results
ensemble_results = pd.concat([test_Survived_rfc,
                              test_Survived_exttc,
                              test_Survived_svc,
                              test_Survived_ada,
                              test_Survived_gbc,
                              test_Survived_xgbc] ,axis=1)

fig, ax = plt.subplots(figsize=(8,8))
g = sns.heatmap(ensemble_results.corr(), annot=True, ax=ax)
